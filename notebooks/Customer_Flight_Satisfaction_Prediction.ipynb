# %% [markdown]
# # Context and Defining Problem Statement
#
# The data we have at hand is of passengers and their feedback regarding their flight experience.
#
# Each row is one passenger. Apart from the  feedback from the customers accross various attributes(15 in total) like food, online_support, cleanliness etc, we have data about the customers' age, loyalty to the airline, gender and class.
#
# The target column is a binary variable which tells us if the customer is satisfied or neutral/dissatisfied
#
# The task at hand is to analyze reasons for customers' satisfaction or dissatisfaction.
#
# And finally, we build a model to predict customer satisfaction using all or some of the data we have

# %% [markdown]
# # Steps -
# 1. Data loading and preprocessing
# 2. Exploratory Data Analysis
# 3. Model building and evaluation
# 4. Model Tuning
# 5. Dimensionality Reduction

# %% [markdown]
# # Data loading and preprocessing

# %% [markdown]
# ### 1. Import Pandas, Numpy, pyplot and seaborn

# %%
#Import necessary libraries
# %matplotlib inline
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
import warnings
warnings.filterwarnings("ignore")  # Not always recommended, but jsut so our notebook looks clean for this activity

# %% [markdown]
# ### 2. Import the dataframes that are needed
# - Import "Flight data_Train.csv" and "Surveydata_Train.csv"

# %%
df1 = pd.read_csv("../data/Flight_data_Train.csv")  # Read the data regarding customer attributes
df2 = pd.read_csv("../data/Surveydata_Train.csv")   # Feedback data from customers

# %%
df1.columns
# Out:
# Index(['ID', 'Gender', 'CustomerType', 'Age', 'TypeTravel', 'Class',
#        'Flight_Distance', 'DepartureDelayin_Mins', 'ArrivalDelayin_Mins'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Id', 'Satisfaction', 'Seat_comfort',
#        'Departure.Arrival.time_convenient', 'Food_drink', 'Gate_location',
#        'Inflightwifi_service', 'Inflight_entertainment', 'Online_support',
#        'Ease_of_Onlinebooking', 'Onboard_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Cleanliness',
#        'Online_boarding'],
#       dtype='object')

# %%
df1.head()
# Out:
#        ID  Gender    CustomerType  Age       TypeTravel Class  \
# 0  149965  Female  Loyal Customer   65  Personal Travel   Eco
# 1  149966  Female  Loyal Customer   15  Personal Travel   Eco
# 2  149967  Female  Loyal Customer   60  Personal Travel   Eco
# 3  149968  Female  Loyal Customer   70  Personal Travel   Eco
# 4  149969    Male  Loyal Customer   30              NaN   Eco
#
#    Flight_Distance  DepartureDelayin_Mins  ArrivalDelayin_Mins
# 0              265                      0                  0.0
# 1             2138                      0                  0.0
# 2              623                      0                  0.0
# 3              354                      0                  0.0
# 4             1894                      0                  0.0

# %%
df2.head()
# Out:
#        Id             Satisfaction Seat_comfort  \
# 0  198671  neutral or dissatisfied         poor
# 1  193378                satisfied    excellent
# 2  174522                satisfied         good
# 3  191830                satisfied         good
# 4  221497                satisfied         good
#
#   Departure.Arrival.time_convenient  Food_drink Gate_location  \
# 0                        acceptable  acceptable    manageable
# 1                  need improvement   excellent    Convinient
# 2                              good        good    manageable
# 3                              good        good    manageable
# 4                              good         NaN    Convinient
#
#   Inflightwifi_service Inflight_entertainment Online_support  \
# 0                 poor       need improvement           poor
# 1           acceptable              excellent     acceptable
# 2           acceptable              excellent      excellent
# 3                 poor                   good           poor
# 4                 good                   good           good
#
#   Ease_of_Onlinebooking   Onboard_service Leg_room_service  Baggage_handling  \
# 0                  poor        acceptable       acceptable              poor
# 1            acceptable              good       acceptable         excellent
# 2      need improvement  need improvement             good  need improvement
# 3                  poor              poor             good              poor
# 4                  good              good             good              good
#
#     Checkin_service       Cleanliness Online_boarding
# 0  need improvement  need improvement            poor
# 1        acceptable         excellent      acceptable
# 2         excellent  need improvement       excellent
# 3        acceptable        acceptable            poor
# 4         excellent              good            good

# %% [markdown]
# ### 3. Join the two dataframes using the 'id' column as the primary key
# - Rename the Id column of one dataframe so that there "id" column name becomes same

# %%
#Using pandas' Join method
#c = a.join(b)  # Joining two dfs on the 'Id' column

df = df2.set_index("Id").join(df1.set_index("ID"))


print(df.shape)
df.head()  # the combined dataframe
# Out:
# (90917, 23)
#                    Satisfaction Seat_comfort  \
# Id
# 198671  neutral or dissatisfied         poor
# 193378                satisfied    excellent
# 174522                satisfied         good
# 191830                satisfied         good
# 221497                satisfied         good
#
#        Departure.Arrival.time_convenient  Food_drink Gate_location  \
# Id
# 198671                        acceptable  acceptable    manageable
# 193378                  need improvement   excellent    Convinient
# 174522                              good        good    manageable
# 191830                              good        good    manageable
# 221497                              good         NaN    Convinient
#
#        Inflightwifi_service Inflight_entertainment Online_support  \
# Id
# 198671                 poor       need improvement           poor
# 193378           acceptable              excellent     acceptable
# 174522           acceptable              excellent      excellent
# 191830                 poor                   good           poor
# 221497                 good                   good           good
#
#        Ease_of_Onlinebooking   Onboard_service  ...       Cleanliness  \
# Id                                              ...
# 198671                  poor        acceptable  ...  need improvement
# 193378            acceptable              good  ...         excellent
# 174522      need improvement  need improvement  ...  need improvement
# 191830                  poor              poor  ...        acceptable
# 221497                  good              good  ...              good
#
#        Online_boarding  Gender       CustomerType Age       TypeTravel  \
# Id
# 198671            poor    Male     Loyal Customer  30  Business travel
# 193378      acceptable  Female  disloyal Customer  20              NaN
# 174522       excellent  Female                NaN  55  Personal Travel
# 191830            poor    Male  disloyal Customer  24  Business travel
# 221497            good    Male     Loyal Customer  32  Business travel
#
#            Class  Flight_Distance DepartureDelayin_Mins ArrivalDelayin_Mins
# Id
# 198671  Business             1354                    11                 8.0
# 193378  Business             1439                     6                 0.0
# 174522  Eco Plus              976                     4                 0.0
# 191830       Eco             2291                     0                 0.0
# 221497  Business             3974                     0                 0.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 4. Print the number of missing values in each of the columns

# %%
df.isna().sum()
# Out:
# Satisfaction                            0
# Seat_comfort                            0
# Departure.Arrival.time_convenient    8244
# Food_drink                           8181
# Gate_location                           0
# Inflightwifi_service                    0
# Inflight_entertainment                  0
# Online_support                          0
# Ease_of_Onlinebooking                   0
# Onboard_service                      7179
# Leg_room_service                        0
# Baggage_handling                        0
# Checkin_service                         0
# Cleanliness                             0
# Online_boarding                         0
# Gender                                  0
# CustomerType                         9099
# Age                                     0
# TypeTravel                           9088
# Class                                   0
# Flight_Distance                         0
# DepartureDelayin_Mins                   0
# ArrivalDelayin_Mins                   284
# dtype: int64

# %% [markdown]
# ### 5. Fill missing values with mean and check the shape of the dataframe before and after dropping the rows
# - Fill null values in ArrivalDelayin_Mins with mean
# - After that drop all the rows with null values

# %%
# Since there are very less null values in the 'ArrivalDelayin_Mins' column, lets impute with mean

df.ArrivalDelayin_Mins.fillna(df.ArrivalDelayin_Mins.mean(), inplace = True)

# %%
# # Alternate way - 1

# df.ArrivalDelayin_Mins.replace({np.nan  : df.ArrivalDelayin_Mins.mean()}, inplace = True)

# %%
# # Alternate way - 2

# from sklearn.impute import SimpleImputer

# imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean') 

# df['ArrivalDelayin_Mins'] = imputer.fit_transform(df['ArrivalDelayin_Mins'].values.reshape(-1,1))

# # the imputer algorithm takes n-dimensional array and since it was throwing an error asking to reshape. Hence the reshape

# %%
df.ArrivalDelayin_Mins.isna().sum()
# Out:
# 0

# %%
# Rest other missing values are filled with not_captured.
#It can be done in other way also or also can be dropped according to the problem and business context.
df.fillna("not_captured", inplace = True)

# %%
print(df.shape)
# Out:
# (90917, 23)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### 6. Print correlation

# %%
cor = df.corr() # It will show correlation of only numerical variables here.

# %%
cor[cor >0.2]
# Out:
#                        Age  Flight_Distance  DepartureDelayin_Mins  \
# Age                    1.0              NaN                    NaN
# Flight_Distance        NaN              1.0                    NaN
# DepartureDelayin_Mins  NaN              NaN                1.00000
# ArrivalDelayin_Mins    NaN              NaN                0.96112
#
#                        ArrivalDelayin_Mins
# Age                                    NaN
# Flight_Distance                        NaN
# DepartureDelayin_Mins              0.96112
# ArrivalDelayin_Mins                1.00000

# %%
to_drop = ['DepartureDelayin_Mins']

# %% [markdown]
# - There is just one obvious correlation that we can see that is between arrival delay and departure delay

# %% [markdown]
# ### Feedback columns
# * 'Seat_comfort'
# * 'Departure.Arrival.time_convenient'
# * 'Food_drink'
# * 'Gate_location'
# * 'Inflightwifi_service'
# * 'Inflight_entertainment'
# * 'Online_support'
# * 'Ease_of_Onlinebooking'
# * 'Onboard_service'
# * 'Leg_room_service'
# * 'Baggage_handling'
# * 'Checkin_service'
# * 'Cleanliness'
# * 'Online_boarding'

# %% [markdown]
# ### 7. Manually encode these variables(printed above) such that they follow an order based on the meaning.
# ### Example: awful = 1, unpleasent = 2, decent = 3, good = 4, great = 5

# %%
# Manual label encoding
# It is a bit of a subjective task. Hence, go ahead in the way you find appropriate

df.replace({'extremely poor' : 0, 'poor' : 1, 'need improvement' : 2, 'acceptable' : 3, 
            'good' : 4, 'excellent' : 5, 'not_captured' : 2}, inplace = True)  

df.replace({'very inconvinient' : 0, 'Inconvinient' : 1, 'need improvement' : 2, 'manageable' : 3,
            'Convinient' : 4, 'very convinient' : 5}, inplace = True)

# %%
df.head()
# Out:
#                    Satisfaction  Seat_comfort  \
# Id
# 198671  neutral or dissatisfied             1
# 193378                satisfied             5
# 174522                satisfied             4
# 191830                satisfied             4
# 221497                satisfied             4
#
#         Departure.Arrival.time_convenient  Food_drink  Gate_location  \
# Id
# 198671                                  3           3              3
# 193378                                  2           5              4
# 174522                                  4           4              3
# 191830                                  4           4              3
# 221497                                  4           2              4
#
#         Inflightwifi_service  Inflight_entertainment  Online_support  \
# Id
# 198671                     1                       2               1
# 193378                     3                       5               3
# 174522                     3                       5               5
# 191830                     1                       4               1
# 221497                     4                       4               4
#
#         Ease_of_Onlinebooking  Onboard_service  ...  Cleanliness  \
# Id                                              ...
# 198671                      1                3  ...            2
# 193378                      3                4  ...            5
# 174522                      2                2  ...            2
# 191830                      1                1  ...            3
# 221497                      4                4  ...            4
#
#         Online_boarding  Gender       CustomerType  Age       TypeTravel  \
# Id
# 198671                1    Male     Loyal Customer   30  Business travel
# 193378                3  Female  disloyal Customer   20                2
# 174522                5  Female                  2   55  Personal Travel
# 191830                1    Male  disloyal Customer   24  Business travel
# 221497                4    Male     Loyal Customer   32  Business travel
#
#            Class  Flight_Distance DepartureDelayin_Mins ArrivalDelayin_Mins
# Id
# 198671  Business             1354                    11                 8.0
# 193378  Business             1439                     6                 0.0
# 174522  Eco Plus              976                     4                 0.0
# 191830       Eco             2291                     0                 0.0
# 221497  Business             3974                     0                 0.0
#
# [5 rows x 23 columns]

# %%
df['Departure.Arrival.time_convenient'].value_counts()
# Out:
# 2    22783
# 4    18840
# 5    17079
# 3    14806
# 1    13210
# 0     4199
# Name: Departure.Arrival.time_convenient, dtype: int64

# %% [markdown]
# ### 9. Draw all the insights that you can from the plots

# %% [markdown]
# **Green and orange bars are counts of satisfied and dissatisfied customers respectively. We want to look for areas where there is a visually significant difference between the length of the stacked bars**
#
# - From the plots above,
#     - Seating comfort can cause high levels of satisfaction to customers. Hardly any people who rated highly for seat_comfort were dissatisfied
#     - A similar case with respect to inflight_entertainment. In this case, having less entertainment seems to have caused far more dissatisfaction compared to bad seating.
#     - Difference is observed in ease_of_online_booking quiet evidently

# %% [markdown]
# ### 10. Print the average feedback score
# - When Satisfaction columns equals 'satisfied'
# - When Satisfaction columns is not equal to 'satisfied'

# %%
df
# Out:
#                    Satisfaction  Seat_comfort  \
# Id
# 198671  neutral or dissatisfied             1
# 193378                satisfied             5
# 174522                satisfied             4
# 191830                satisfied             4
# 221497                satisfied             4
# ...                         ...           ...
# 152951                satisfied             0
# 220134                satisfied             1
# 174403                satisfied             4
# 224128                satisfied             4
# 186039  neutral or dissatisfied             3
#
#         Departure.Arrival.time_convenient  Food_drink  Gate_location  \
# Id
# 198671                                  3           3              3
# 193378                                  2           5              4
# 174522                                  4           4              3
# 191830                                  4           4              3
# 221497                                  4           2              4
# ...                                   ...         ...            ...
# 152951                                  4           0              4
# 220134                                  1           1              1
# 174403                                  4           4              3
# 224128                                  1           5              5
# 186039                                  2           2              3
#
#         Inflightwifi_service  Inflight_entertainment  Online_support  \
# Id
# 198671                     1                       2               1
# 193378                     3                       5               3
# 174522                     3                       5               5
# 191830                     1                       4               1
# 221497                     4                       4               4
# ...                      ...                     ...             ...
# 152951                     2                       5               4
# 220134                     4                       5               5
# 174403                     4                       4               5
# 224128                     4                       4               4
# 186039                     4                       3               4
#
#         Ease_of_Onlinebooking  Onboard_service  ...  Cleanliness  \
# Id                                              ...
# 198671                      1                3  ...            2
# 193378                      3                4  ...            5
# 174522                      2                2  ...            2
# 191830                      1                1  ...            3
# 221497                      4                4  ...            4
# ...                       ...              ...  ...          ...
# 152951                      4                4  ...            4
# 220134                      4                4  ...            4
# 174403                      1                1  ...            1
# 224128                      4                4  ...            3
# 186039                      4                1  ...            4
#
#         Online_boarding  Gender       CustomerType  Age       TypeTravel  \
# Id
# 198671                1    Male     Loyal Customer   30  Business travel
# 193378                3  Female  disloyal Customer   20                2
# 174522                5  Female                  2   55  Personal Travel
# 191830                1    Male  disloyal Customer   24  Business travel
# 221497                4    Male     Loyal Customer   32  Business travel
# ...                 ...     ...                ...  ...              ...
# 152951                3  Female                  2   46  Personal Travel
# 220134                4  Female     Loyal Customer   45                2
# 174403                5  Female     Loyal Customer   67                2
# 224128                4  Female     Loyal Customer   37  Business travel
# 186039                4    Male  disloyal Customer   43  Business travel
#
#            Class  Flight_Distance DepartureDelayin_Mins ArrivalDelayin_Mins
# Id
# 198671  Business             1354                    11                 8.0
# 193378  Business             1439                     6                 0.0
# 174522  Eco Plus              976                     4                 0.0
# 191830       Eco             2291                     0                 0.0
# 221497  Business             3974                     0                 0.0
# ...          ...              ...                   ...                 ...
# 152951       Eco             1143                     0                 0.0
# 220134  Business             3585                     1                 0.0
# 174403       Eco             2563                     3                 2.0
# 224128       Eco             1027                     0                 0.0
# 186039  Business             1491                    53                53.0
#
# [90917 rows x 23 columns]

# %%
Feedback_cols = ['Seat_comfort', 'Departure.Arrival.time_convenient',
                 'Food_drink', 'Gate_location', 'Inflightwifi_service',
                 'Inflight_entertainment', 'Online_support', 'Ease_of_Onlinebooking', 
                 'Onboard_service', 'Leg_room_service', 'Baggage_handling', 'Checkin_service',
                 'Cleanliness', 'Online_boarding']

# %%
df.groupby('Satisfaction').mean() # Average rating of individual feedback attributes across satisfaction levels
# Out:
#                          Seat_comfort  Departure.Arrival.time_convenient  \
# Satisfaction
# neutral or dissatisfied      2.469239                           2.928127
# satisfied                    3.144511                           2.882559
#
#                          Food_drink  Gate_location  Inflightwifi_service  \
# Satisfaction
# neutral or dissatisfied    2.603606       3.007848              2.923219
# satisfied                  2.914210       2.975985              3.523121
#
#                          Inflight_entertainment  Online_support  \
# Satisfaction
# neutral or dissatisfied                2.613058        2.962071
# satisfied                              4.021543        3.979864
#
#                          Ease_of_Onlinebooking  Onboard_service  \
# Satisfaction
# neutral or dissatisfied               2.858563         2.900209
# satisfied                             3.985953         3.723297
#
#                          Leg_room_service  Baggage_handling  Checkin_service  \
# Satisfaction
# neutral or dissatisfied          3.053164          3.368209         2.970673
# satisfied                        3.845803          3.969695         3.646852
#
#                          Cleanliness  Online_boarding        Age  \
# Satisfaction
# neutral or dissatisfied     3.381159         2.873530  37.493221
# satisfied                   3.978115         3.748598  41.063222
#
#                          Flight_Distance  DepartureDelayin_Mins  \
# Satisfaction
# neutral or dissatisfied      2026.647512              17.793177
# satisfied                    1944.396194              12.117220
#
#                          ArrivalDelayin_Mins
# Satisfaction
# neutral or dissatisfied            18.432402
# satisfied                          12.268821

# %% [markdown]
# ### 11. Draw any insights that you can from the above values

# %% [markdown]
# - Observe the Exreme values (lower side for 'dissatisfaction' and higher side for 'satisfaction')
# - Bad seats are a strong cause for customer dissatisfication
# - Time convenience doesn't seem to be that big of a deal
# - Dissatisfied customers had some bad experiences with food but average food seems to satisfy most people
# - Gate location is totally irrelevant
# - Wifi is quiet a factor. On an average, having good wifi yeilded customer satisfaction
# - Easy online booking facility seems to be very important for customer satisfaction
# - In flight entertainment seems to be a deal breaker

# %% [markdown]
# ### 12. Achieve the following
# - Print the number of people who are more than just satisfied with the "Inflight_entertainment" and yet were dissatisfied overall
# - Print the number of people who are more than just satisfied with the "Inflight_entertainment" and were satisfied overall

# %%
df.Inflight_entertainment.value_counts()
# Out:
# 4    29373
# 5    20786
# 3    16995
# 2    13527
# 1     8198
# 0     2038
# Name: Inflight_entertainment, dtype: int64

# %%
# Number of people who got entertained well but were dissatisfied in the end
entertained_and_dissatisfied = df[(df.Inflight_entertainment > 3) & (df.Satisfaction != 'satisfied')]
print(100 * entertained_and_dissatisfied.shape[0]/df.shape[0], 'percent')
# Out:
# 10.11581992366664 percent

# %%
# Number of customers who got entertained and were satisfied with the flight
entertained_and_satisfied = df[(df.Inflight_entertainment <= 3) & (df.Satisfaction == 'satisfied')]
print(100 * entertained_and_satisfied.shape[0]/df.shape[0], 'percent')
# Out:
# 9.67805800895322 percent

# %% [markdown]
# ### 13. Create a new column which is the mean of 'Ease_of_Onlinebooking', 'Online_boarding', 'Online_support' and name it "avg_feedback_of_online_services".
#
# DIY : If online services has a bad ratings then what is the average ratings of other feedback attributes?
# And how does it impact Final Satisfaction of customers?

# %%
online_df = df.loc[:, ['Ease_of_Onlinebooking', 'Online_boarding', 'Online_support']]
online_df['avg_feedback_of_online_services'] = online_df.median(axis = 1)

online_df['avg_feedback_of_online_services'].value_counts()
# Out:
# 4.0    31581
# 5.0    21334
# 3.0    17028
# 2.0    12840
# 1.0     8125
# 0.0        9
# Name: avg_feedback_of_online_services, dtype: int64

# %% [markdown]
# -You might find that -  **A lot of things had to go well to satisfy the customers when the only services had a bad rating**

# %% [markdown]
# # Model building and evaluation

# %% [markdown]
# ### 14. Encode the columns "Gender", "CustomerType", "TypeTravel", "Class", "Satisfaction"
# - Use manual encoding or other type of encoding

# %%
# Number of classes in each of the categorical attributes
for i in df.columns:
    if df[i].dtype == 'O':
        print(i, '->', len(df[i].value_counts()))
# Out:
# Satisfaction -> 2
# Gender -> 2
# CustomerType -> 3
# TypeTravel -> 3
# Class -> 3

# %%
df.Class.value_counts()
# Out:
# Business    43535
# Eco         40758
# Eco Plus     6624
# Name: Class, dtype: int64

# %%
# #Manuanl Encoding
# df.replace({'Loyal Customer' : 1, 'disloyal Customer' : 0,
#                'Business travel' : 1, 'Personal Travel' : 0,
#               'Female' : 0, 'Male' : 1,
#                'satisfied' : 1, 'neutral or dissatisfied' : 0, 'Eco Plus': 0 , 'Eco': 1, 'Business': 2}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90917 entries, 198671 to 186039
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Satisfaction                       90917 non-null  object
#  1   Seat_comfort                       90917 non-null  int64
#  2   Departure.Arrival.time_convenient  90917 non-null  int64
#  3   Food_drink                         90917 non-null  int64
#  4   Gate_location                      90917 non-null  int64
#  5   Inflightwifi_service               90917 non-null  int64
#  6   Inflight_entertainment             90917 non-null  int64
#  7   Online_support                     90917 non-null  int64
#  8   Ease_of_Onlinebooking              90917 non-null  int64
#  9   Onboard_service                    90917 non-null  int64
#  10  Leg_room_service                   90917 non-null  int64
#  11  Baggage_handling                   90917 non-null  int64
#  12  Checkin_service                    90917 non-null  int64
#  13  Cleanliness                        90917 non-null  int64
#  14  Online_boarding                    90917 non-null  int64
#  15  Gender                             90917 non-null  object
#  16  CustomerType                       90917 non-null  object
#  17  Age                                90917 non-null  int64
#  18  TypeTravel                         90917 non-null  object
#  19  Class                              90917 non-null  object
#  20  Flight_Distance                    90917 non-null  int64
#  21  DepartureDelayin_Mins              90917 non-null  int64
#  22  ArrivalDelayin_Mins                90917 non-null  float64
# dtypes: float64(1), int64(17), object(5)
# memory usage: 18.7+ MB

# %%
df[['Gender','CustomerType','TypeTravel','Class']]
# Out:
#         Gender       CustomerType       TypeTravel     Class
# Id
# 198671    Male     Loyal Customer  Business travel  Business
# 193378  Female  disloyal Customer                2  Business
# 174522  Female                  2  Personal Travel  Eco Plus
# 191830    Male  disloyal Customer  Business travel       Eco
# 221497    Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 152951  Female                  2  Personal Travel       Eco
# 220134  Female     Loyal Customer                2  Business
# 174403  Female     Loyal Customer                2       Eco
# 224128  Female     Loyal Customer  Business travel       Eco
# 186039    Male  disloyal Customer  Business travel  Business
#
# [90917 rows x 4 columns]

# %%
#onehotencoding
df_coded = pd.get_dummies(df[['Gender','CustomerType','TypeTravel','Class']],drop_first=True)

# %%
df_coded
# Out:
#         Gender_Male  CustomerType_Loyal Customer  \
# Id
# 198671            1                            1
# 193378            0                            0
# 174522            0                            0
# 191830            1                            0
# 221497            1                            1
# ...             ...                          ...
# 152951            0                            0
# 220134            0                            1
# 174403            0                            1
# 224128            0                            1
# 186039            1                            0
#
#         CustomerType_disloyal Customer  TypeTravel_Business travel  \
# Id
# 198671                               0                           1
# 193378                               1                           0
# 174522                               0                           0
# 191830                               1                           1
# 221497                               0                           1
# ...                                ...                         ...
# 152951                               0                           0
# 220134                               0                           0
# 174403                               0                           0
# 224128                               0                           1
# 186039                               1                           1
#
#         TypeTravel_Personal Travel  Class_Eco  Class_Eco Plus
# Id
# 198671                           0          0               0
# 193378                           0          0               0
# 174522                           1          0               1
# 191830                           0          1               0
# 221497                           0          0               0
# ...                            ...        ...             ...
# 152951                           1          1               0
# 220134                           0          0               0
# 174403                           0          1               0
# 224128                           0          1               0
# 186039                           0          0               0
#
# [90917 rows x 7 columns]

# %%
# #Alternate method - 1
# #Use categoryencoding
# import category_encoders as ce
# cols = ["Gender", "CustomerType", "TypeTravel", "Class", "Satisfaction"]

# ce = ce.TargetEncoder()
# df[cols] = ce.fit_transform(df[cols])


                             
# Alternate - 2 - Onehotencoding
# You can learn more about encoding here - https://kiwidamien.github.io/encoding-categorical-variables.html

# %%
df_coded.columns
# Out:
# Index(['Gender_Male', 'CustomerType_Loyal Customer',
#        'CustomerType_disloyal Customer', 'TypeTravel_Business travel',
#        'TypeTravel_Personal Travel', 'Class_Eco', 'Class_Eco Plus'],
#       dtype='object')

# %%
df_coded.head()
# Out:
#         Gender_Male  CustomerType_Loyal Customer  \
# Id
# 198671            1                            1
# 193378            0                            0
# 174522            0                            0
# 191830            1                            0
# 221497            1                            1
#
#         CustomerType_disloyal Customer  TypeTravel_Business travel  \
# Id
# 198671                               0                           1
# 193378                               1                           0
# 174522                               0                           0
# 191830                               1                           1
# 221497                               0                           1
#
#         TypeTravel_Personal Travel  Class_Eco  Class_Eco Plus
# Id
# 198671                           0          0               0
# 193378                           0          0               0
# 174522                           1          0               1
# 191830                           0          1               0
# 221497                           0          0               0

# %%
df.drop(columns=['Gender','CustomerType','TypeTravel','Class'],inplace=True)

# %%
df = pd.concat([df,df_coded],axis=1)

# %%
df
# Out:
#                    Satisfaction  Seat_comfort  \
# Id
# 198671  neutral or dissatisfied             1
# 193378                satisfied             5
# 174522                satisfied             4
# 191830                satisfied             4
# 221497                satisfied             4
# ...                         ...           ...
# 152951                satisfied             0
# 220134                satisfied             1
# 174403                satisfied             4
# 224128                satisfied             4
# 186039  neutral or dissatisfied             3
#
#         Departure.Arrival.time_convenient  Food_drink  Gate_location  \
# Id
# 198671                                  3           3              3
# 193378                                  2           5              4
# 174522                                  4           4              3
# 191830                                  4           4              3
# 221497                                  4           2              4
# ...                                   ...         ...            ...
# 152951                                  4           0              4
# 220134                                  1           1              1
# 174403                                  4           4              3
# 224128                                  1           5              5
# 186039                                  2           2              3
#
#         Inflightwifi_service  Inflight_entertainment  Online_support  \
# Id
# 198671                     1                       2               1
# 193378                     3                       5               3
# 174522                     3                       5               5
# 191830                     1                       4               1
# 221497                     4                       4               4
# ...                      ...                     ...             ...
# 152951                     2                       5               4
# 220134                     4                       5               5
# 174403                     4                       4               5
# 224128                     4                       4               4
# 186039                     4                       3               4
#
#         Ease_of_Onlinebooking  Onboard_service  ...  Flight_Distance  \
# Id                                              ...
# 198671                      1                3  ...             1354
# 193378                      3                4  ...             1439
# 174522                      2                2  ...              976
# 191830                      1                1  ...             2291
# 221497                      4                4  ...             3974
# ...                       ...              ...  ...              ...
# 152951                      4                4  ...             1143
# 220134                      4                4  ...             3585
# 174403                      1                1  ...             2563
# 224128                      4                4  ...             1027
# 186039                      4                1  ...             1491
#
#         DepartureDelayin_Mins  ArrivalDelayin_Mins  Gender_Male  \
# Id
# 198671                     11                  8.0            1
# 193378                      6                  0.0            0
# 174522                      4                  0.0            0
# 191830                      0                  0.0            1
# 221497                      0                  0.0            1
# ...                       ...                  ...          ...
# 152951                      0                  0.0            0
# 220134                      1                  0.0            0
# 174403                      3                  2.0            0
# 224128                      0                  0.0            0
# 186039                     53                 53.0            1
#
#         CustomerType_Loyal Customer  CustomerType_disloyal Customer  \
# Id
# 198671                            1                               0
# 193378                            0                               1
# 174522                            0                               0
# 191830                            0                               1
# 221497                            1                               0
# ...                             ...                             ...
# 152951                            0                               0
# 220134                            1                               0
# 174403                            1                               0
# 224128                            1                               0
# 186039                            0                               1
#
#         TypeTravel_Business travel  TypeTravel_Personal Travel  Class_Eco  \
# Id
# 198671                           1                           0          0
# 193378                           0                           0          0
# 174522                           0                           1          0
# 191830                           1                           0          1
# 221497                           1                           0          0
# ...                            ...                         ...        ...
# 152951                           0                           1          1
# 220134                           0                           0          0
# 174403                           0                           0          1
# 224128                           1                           0          1
# 186039                           1                           0          0
#
#         Class_Eco Plus
# Id
# 198671               0
# 193378               0
# 174522               1
# 191830               0
# 221497               0
# ...                ...
# 152951               0
# 220134               0
# 174403               0
# 224128               0
# 186039               0
#
# [90917 rows x 26 columns]

# %% [markdown]
# # Scaling

# %%
# #MinMax Scaling - scales the data set such that all feature values are in the range [0, 1].
# #StandardScaler - removes the mean and scales the data to unit variance


# You can learn about other scalers here -
# https://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html

# %%
df = df.reset_index(drop=True)
cols_to_scale = ['Age', 'Flight_Distance','DepartureDelayin_Mins', 'ArrivalDelayin_Mins']
df[cols_to_scale]
# Out:
#        Age  Flight_Distance  DepartureDelayin_Mins  ArrivalDelayin_Mins
# 0       30             1354                     11                  8.0
# 1       20             1439                      6                  0.0
# 2       55              976                      4                  0.0
# 3       24             2291                      0                  0.0
# 4       32             3974                      0                  0.0
# ...    ...              ...                    ...                  ...
# 90912   46             1143                      0                  0.0
# 90913   45             3585                      1                  0.0
# 90914   67             2563                      3                  2.0
# 90915   37             1027                      0                  0.0
# 90916   43             1491                     53                 53.0
#
# [90917 rows x 4 columns]

# %%
#Here we are going to use StandardScaler to scale our data.
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
#What all columns to scale? I have preferred all columns except onehotencoded columns and target columns as
#scaling of target feature will not change anything as they already have values like 0 and 1 only.
#You may only scale numerical features and leave categorical features as required according to business problem need and results.
# cols_to_scale = ['Seat_comfort', 'Departure.Arrival.time_convenient',
#        'Food_drink', 'Gate_location', 'Inflightwifi_service',
#        'Inflight_entertainment', 'Online_support', 'Ease_of_Onlinebooking',
#        'Onboard_service', 'Leg_room_service', 'Baggage_handling',
#        'Checkin_service', 'Cleanliness', 'Online_boarding',
#        'Age', 'Flight_Distance','DepartureDelayin_Mins', 'ArrivalDelayin_Mins']
cols_to_scale = ['Age', 'Flight_Distance','DepartureDelayin_Mins', 'ArrivalDelayin_Mins']
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale].to_numpy())

# %%
df.describe()
# Out:
#        Seat_comfort  Departure.Arrival.time_convenient    Food_drink  \
# count  90917.000000                       90917.000000  90917.000000
# mean       2.838831                           2.903186      2.773607
# std        1.393582                           1.482137      1.397892
# min        0.000000                           0.000000      0.000000
# 25%        2.000000                           2.000000      2.000000
# 50%        3.000000                           3.000000      3.000000
# 75%        4.000000                           4.000000      4.000000
# max        5.000000                           5.000000      5.000000
#
#        Gate_location  Inflightwifi_service  Inflight_entertainment  \
# count   90917.000000          90917.000000            90917.000000
# mean        2.990409              3.251559                3.383955
# std         1.307902              1.320115                1.342158
# min         0.000000              0.000000                0.000000
# 25%         2.000000              2.000000                2.000000
# 50%         3.000000              3.000000                4.000000
# 75%         4.000000              4.000000                4.000000
# max         5.000000              5.000000                5.000000
#
#        Online_support  Ease_of_Onlinebooking  Onboard_service  \
# count    90917.000000           90917.000000     90917.000000
# mean         3.519133               3.475610         3.350704
# std          1.307794               1.304658         1.280816
# min          0.000000               0.000000         0.000000
# 25%          3.000000               2.000000         2.000000
# 50%          4.000000               4.000000         4.000000
# 75%          5.000000               5.000000         4.000000
# max          5.000000               5.000000         5.000000
#
#        Leg_room_service  ...  Flight_Distance  DepartureDelayin_Mins  \
# count      90917.000000  ...     9.091700e+04           9.091700e+04
# mean           3.486994  ...     9.558100e-17           6.252232e-19
# std            1.291758  ...     1.000005e+00           1.000005e+00
# min            0.000000  ...    -1.881260e+00          -3.798023e-01
# 25%            2.000000  ...    -6.054198e-01          -3.798023e-01
# 50%            4.000000  ...    -5.320492e-02          -3.798023e-01
# 75%            5.000000  ...     5.457583e-01          -6.947658e-02
# max            5.000000  ...     4.838815e+00           4.079008e+01
#
#        ArrivalDelayin_Mins   Gender_Male  CustomerType_Loyal Customer  \
# count         9.091700e+04  90917.000000                 90917.000000
# mean         -4.845480e-18      0.491998                     0.735803
# std           1.000005e+00      0.499939                     0.440907
# min          -3.863514e-01      0.000000                     0.000000
# 25%          -3.863514e-01      0.000000                     0.000000
# 50%          -3.863514e-01      0.000000                     1.000000
# 75%          -5.282384e-02      1.000000                     1.000000
# max           4.025270e+01      1.000000                     1.000000
#
#        CustomerType_disloyal Customer  TypeTravel_Business travel  \
# count                    90917.000000                90917.000000
# mean                         0.164117                    0.621237
# std                          0.370383                    0.485082
# min                          0.000000                    0.000000
# 25%                          0.000000                    0.000000
# 50%                          0.000000                    1.000000
# 75%                          0.000000                    1.000000
# max                          1.000000                    1.000000
#
#        TypeTravel_Personal Travel     Class_Eco  Class_Eco Plus
# count                90917.000000  90917.000000    90917.000000
# mean                     0.278804      0.448299        0.072858
# std                      0.448413      0.497323        0.259904
# min                      0.000000      0.000000        0.000000
# 25%                      0.000000      0.000000        0.000000
# 50%                      0.000000      0.000000        0.000000
# 75%                      1.000000      1.000000        0.000000
# max                      1.000000      1.000000        1.000000
#
# [8 rows x 25 columns]

# %%
df.head()
# Out:
#               Satisfaction  Seat_comfort  Departure.Arrival.time_convenient  \
# 0  neutral or dissatisfied             1                                  3
# 1                satisfied             5                                  2
# 2                satisfied             4                                  4
# 3                satisfied             4                                  4
# 4                satisfied             4                                  4
#
#    Food_drink  Gate_location  Inflightwifi_service  Inflight_entertainment  \
# 0           3              3                     1                       2
# 1           5              4                     3                       5
# 2           4              3                     3                       5
# 3           4              3                     1                       4
# 4           2              4                     4                       4
#
#    Online_support  Ease_of_Onlinebooking  Onboard_service  ...  \
# 0               1                      1                3  ...
# 1               3                      3                4  ...
# 2               5                      2                2  ...
# 3               1                      1                1  ...
# 4               4                      4                4  ...
#
#    Flight_Distance  DepartureDelayin_Mins  ArrivalDelayin_Mins  Gender_Male  \
# 0        -0.611263              -0.095337            -0.181104            1
# 1        -0.528480              -0.224639            -0.386351            0
# 2        -0.979407              -0.276360            -0.386351            0
# 3         0.301303              -0.379802            -0.386351            1
# 4         1.940417              -0.379802            -0.386351            1
#
#    CustomerType_Loyal Customer  CustomerType_disloyal Customer  \
# 0                            1                               0
# 1                            0                               1
# 2                            0                               0
# 3                            0                               1
# 4                            1                               0
#
#    TypeTravel_Business travel  TypeTravel_Personal Travel  Class_Eco  \
# 0                           1                           0          0
# 1                           0                           0          0
# 2                           0                           1          0
# 3                           1                           0          1
# 4                           1                           0          0
#
#    Class_Eco Plus
# 0               0
# 1               0
# 2               1
# 3               0
# 4               0
#
# [5 rows x 26 columns]

# %%
# df = df_coded.copy()

# %% [markdown]
# ### 15. Seperate the column "Satisfaction" from the rest of the columns
# - Create X and y

# %%
#We are going to drop highly correlated feature which we have found before as there features might affect our models.
to_drop.append('Satisfaction')

# %%
to_drop
# Out:
# ['DepartureDelayin_Mins', 'Satisfaction']

# %%
X = df.drop(columns= to_drop)  # Seperating the target and the rest
#X = df.drop(columns= ['Satisfaction'])
y = df.Satisfaction

# %%
X
# Out:
#        Seat_comfort  Departure.Arrival.time_convenient  Food_drink  \
# 0                 1                                  3           3
# 1                 5                                  2           5
# 2                 4                                  4           4
# 3                 4                                  4           4
# 4                 4                                  4           2
# ...             ...                                ...         ...
# 90912             0                                  4           0
# 90913             1                                  1           1
# 90914             4                                  4           4
# 90915             4                                  1           5
# 90916             3                                  2           2
#
#        Gate_location  Inflightwifi_service  Inflight_entertainment  \
# 0                  3                     1                       2
# 1                  4                     3                       5
# 2                  3                     3                       5
# 3                  3                     1                       4
# 4                  4                     4                       4
# ...              ...                   ...                     ...
# 90912              4                     2                       5
# 90913              1                     4                       5
# 90914              3                     4                       4
# 90915              5                     4                       4
# 90916              3                     4                       3
#
#        Online_support  Ease_of_Onlinebooking  Onboard_service  \
# 0                   1                      1                3
# 1                   3                      3                4
# 2                   5                      2                2
# 3                   1                      1                1
# 4                   4                      4                4
# ...               ...                    ...              ...
# 90912               4                      4                4
# 90913               5                      4                4
# 90914               5                      1                1
# 90915               4                      4                4
# 90916               4                      4                1
#
#        Leg_room_service  ...       Age  Flight_Distance  ArrivalDelayin_Mins  \
# 0                     3  ... -0.624412        -0.611263            -0.181104
# 1                     3  ... -1.285363        -0.528480            -0.386351
# 2                     4  ...  1.027966        -0.979407            -0.386351
# 3                     4  ... -1.020982         0.301303            -0.386351
# 4                     4  ... -0.492221         1.940417            -0.386351
# ...                 ...  ...       ...              ...                  ...
# 90912                 5  ...  0.433110        -0.816761            -0.386351
# 90913                 4  ...  0.367015         1.561561            -0.386351
# 90914                 4  ...  1.821108         0.566211            -0.335039
# 90915                 3  ... -0.161746        -0.929736            -0.386351
# 90916                 5  ...  0.234825        -0.477836             0.973415
#
#        Gender_Male  CustomerType_Loyal Customer  \
# 0                1                            1
# 1                0                            0
# 2                0                            0
# 3                1                            0
# 4                1                            1
# ...            ...                          ...
# 90912            0                            0
# 90913            0                            1
# 90914            0                            1
# 90915            0                            1
# 90916            1                            0
#
#        CustomerType_disloyal Customer  TypeTravel_Business travel  \
# 0                                   0                           1
# 1                                   1                           0
# 2                                   0                           0
# 3                                   1                           1
# 4                                   0                           1
# ...                               ...                         ...
# 90912                               0                           0
# 90913                               0                           0
# 90914                               0                           0
# 90915                               0                           1
# 90916                               1                           1
#
#        TypeTravel_Personal Travel  Class_Eco  Class_Eco Plus
# 0                               0          0               0
# 1                               0          0               0
# 2                               1          0               1
# 3                               0          1               0
# 4                               0          0               0
# ...                           ...        ...             ...
# 90912                           1          1               0
# 90913                           0          0               0
# 90914                           0          1               0
# 90915                           0          1               0
# 90916                           0          0               0
#
# [90917 rows x 24 columns]

# %% [markdown]
# ### 16. Create train and test datasets
# - Use train_test_split

# %%
from sklearn.model_selection import train_test_split # Splitting the data for training and testing out model

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 1, stratify = y)

# %%
y_train.value_counts(normalize=True)
# Out:
# satisfied                  0.547318
# neutral or dissatisfied    0.452682
# Name: Satisfaction, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# satisfied                  0.547338
# neutral or dissatisfied    0.452662
# Name: Satisfaction, dtype: float64

# %%
X_train.dtypes
# Out:
# Seat_comfort                           int64
# Departure.Arrival.time_convenient      int64
# Food_drink                             int64
# Gate_location                          int64
# Inflightwifi_service                   int64
# Inflight_entertainment                 int64
# Online_support                         int64
# Ease_of_Onlinebooking                  int64
# Onboard_service                        int64
# Leg_room_service                       int64
# Baggage_handling                       int64
# Checkin_service                        int64
# Cleanliness                            int64
# Online_boarding                        int64
# Age                                  float64
# Flight_Distance                      float64
# ArrivalDelayin_Mins                  float64
# Gender_Male                            uint8
# CustomerType_Loyal Customer            uint8
# CustomerType_disloyal Customer         uint8
# TypeTravel_Business travel             uint8
# TypeTravel_Personal Travel             uint8
# Class_Eco                              uint8
# Class_Eco Plus                         uint8
# dtype: object

# %% [markdown]
# ### 17. Print accuracy
# - Print accuracy on test data using below models
# - Logistic regression model trained using all the attributes
# - Logistic regression model trained using only the feedback columns
# - Decision tree model trained using all the attributes
# - Random forest model trained using all the attributes

# %% [markdown]
# ### Logistic Regression

# %%
#Logistic Regression with only feedback columns
from sklearn.linear_model import LogisticRegression #importing logistic regression

lr = LogisticRegression()

lr.fit(X_train, y_train)

pred = lr.predict(X_test)  # Predictions from logistic regression
logreg_score = lr.score(X_test, y_test)
logreg_score
# Out:
# 0.834007919049714

# %% [markdown]
# Predicting customer satisfaction solely based on the feedback

# %%
#Logistic Regression with only feedback columns
X_train, X_test, y_train, y_test = train_test_split(X.loc[:,Feedback_cols], y, random_state = 1, stratify = y)

lr = LogisticRegression()

lr.fit(X_train, y_train)

pred = lr.predict(X_test)

logreg_feedback_score = lr.score(X_test, y_test)

print(f'Number of features used = {len(X_train.columns)}')
print(f'Accuracy in predicting customer satisfaction solely based on the feedback = {logreg_feedback_score}')
# Out:
# Number of features used = 14
# Accuracy in predicting customer satisfaction solely based on the feedback = 0.8048834139903212

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 1, stratify = y)

dt = DecisionTreeClassifier()

dt.fit(X_train, y_train)

DT_score = dt.score(X_test, y_test)
pred = dt.predict(X_test)

print(f"Decision tree acccuracy score: {DT_score}")
# Out:
# Decision tree acccuracy score: 0.9258688957325121

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(max_depth=10)

rf.fit(X_train, y_train)

RF_score = rf.score(X_test, y_test)

print(f'Random Forest accuracy score = {RF_score}')
# Out:
# Random Forest accuracy score = 0.9264408271007479

# %% [markdown]
# ### 18. Print feature importance
# - Print feature importance of Random Forest

# %%
#Decision Tree 
pd.Series(dt.feature_importances_, X_train.columns ).sort_values(ascending= False)
# Out:
# Inflight_entertainment               0.391439
# Seat_comfort                         0.175919
# Ease_of_Onlinebooking                0.057857
# Flight_Distance                      0.048028
# Checkin_service                      0.025652
# Age                                  0.025647
# Online_boarding                      0.023692
# Inflightwifi_service                 0.023201
# ArrivalDelayin_Mins                  0.022665
# Gate_location                        0.022570
# Leg_room_service                     0.019935
# Cleanliness                          0.016569
# TypeTravel_Personal Travel           0.016154
# Gender_Male                          0.016014
# Online_support                       0.016013
# Baggage_handling                     0.015471
# Departure.Arrival.time_convenient    0.014112
# Class_Eco                            0.013513
# CustomerType_disloyal Customer       0.013195
# Onboard_service                      0.010966
# Food_drink                           0.010751
# CustomerType_Loyal Customer          0.009108
# TypeTravel_Business travel           0.008720
# Class_Eco Plus                       0.002809
# dtype: float64

# %%
#RandomForest
pd.Series(rf.feature_importances_, X_train.columns).sort_values(ascending= False)
# Out:
# Inflight_entertainment               0.254149
# Seat_comfort                         0.141897
# Online_support                       0.082489
# Ease_of_Onlinebooking                0.080846
# Leg_room_service                     0.045429
# Online_boarding                      0.041453
# Onboard_service                      0.039103
# Food_drink                           0.038055
# CustomerType_disloyal Customer       0.035802
# Gender_Male                          0.034299
# Class_Eco                            0.025505
# Cleanliness                          0.024321
# Checkin_service                      0.018305
# CustomerType_Loyal Customer          0.018302
# Baggage_handling                     0.017363
# TypeTravel_Personal Travel           0.017001
# Flight_Distance                      0.015948
# Inflightwifi_service                 0.015207
# TypeTravel_Business travel           0.015029
# Departure.Arrival.time_convenient    0.012851
# Age                                  0.010190
# Gate_location                        0.007877
# ArrivalDelayin_Mins                  0.006614
# Class_Eco Plus                       0.001966
# dtype: float64

# %% [markdown]
# # Model Tuning

# %% [markdown]
# ### 19. Print cross validation score
# - Decision tree model trained using all the attributes
# - Random Forest model trained using all the attributes
# - Fine tuned (using Grid Search or Random Search) Random Forest model
#
# **Display all the scores above with their respective models in a single dataframe**

# %% [markdown]
# Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score,cross_val_predict
#For Decision Tree dt
CV_DT_score = cross_val_score(dt, X_train, y_train, cv = 5).mean()
print(f'Cross validation score of Decision tree = {CV_DT_score}')
# Out:
# Cross validation score of Decision tree = 0.9262909379231168

# %%
#Random Forest rf
CV_RF_score = cross_val_score(rf, X_train, y_train, cv = 5).mean()
print(f'Cross validation score of Random forest = {CV_RF_score}')
# Out:
# Cross validation score of Random forest = 0.9243257995371861

# %% [markdown]
# ### Parameter Tuning Using GridSearch
#
# Doing it only for RandomForest as the mean CV score is better.

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %% [markdown]
# #### RandomCV Search

# %%
3*2*4
# Out:
# 24

# %%
rf_test = RandomForestClassifier(max_depth=10)
import time
start = time.time()
rf_test.fit(X_train, y_train)
end = time.time()
print((end-start)/60," minutes")
# Out:
# 0.1002457062403361  minutes

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
import time
start = time.time()
parameters = {'max_depth': [30, 40, 70],
 'max_features': ['log2', 'sqrt'],
 'min_samples_leaf': [1, 2, 4, 8],
 'n_estimators': [100]}



clf = RandomizedSearchCV(RandomForestClassifier(), parameters, cv = 5, verbose = 2, n_jobs= -1,n_iter=6)
clf.fit(X_train, y_train)

clf.best_params_

end = time.time()
print((end-start)/60," minutes")
# Best parameters
clf.best_params_
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# 1.0691234509150187  minutes
# {'n_estimators': 100,
#  'min_samples_leaf': 1,
#  'max_features': 'log2',
#  'max_depth': 40}

# %%
# rf = RandomForestClassifier(bootstrap= True,
#  max_depth= 20,
#  max_features= 'sqrt',
#  min_samples_leaf= 1,
#  n_estimators= 100)

# rf.fit(X_train, y_train)

RS_RF_score = clf.score(X_test, y_test)

print(f'Random Forest accuracy score with best param = {RS_RF_score}')
# Out:
# Random Forest accuracy score with best param = 0.9528816542014958

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
import time
start = time.time()
# parameters = {'max_depth': [10, 20, 30, 40, 50],
#  'max_features': ['log2', 'sqrt'],
#  'min_samples_leaf': [1, 2, 4, 8],
#  'n_estimators': [100]}

parameters = {'max_depth': [30, 40, 70],
 'max_features': ['log2', 'sqrt'],
 'min_samples_leaf': [1, 2, 4, 8],
 'n_estimators': [100]}

clf_gs = GridSearchCV(RandomForestClassifier(), parameters, cv = 5, verbose = 2, n_jobs= -1)
clf_gs.fit(X, y)

end = time.time()
print((end-start)/60," minutes")

# Best parameters
clf_gs.best_params_
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# 4.310887455940247  minutes
# {'max_depth': 30,
#  'max_features': 'log2',
#  'min_samples_leaf': 1,
#  'n_estimators': 100}

# %%
# rf = RandomForestClassifier(bootstrap= True,
#  max_depth= 50,
#  max_features= 'sqrt',
#  min_samples_leaf= 4,
#  n_estimators= 100)

# rf.fit(X_train, y_train)

GS_RF_score = clf_gs.score(X_test, y_test)

print(f'Random Forest accuracy with Grid Search score with best param = {GS_RF_score}')
# Out:
# Random Forest accuracy with Grid Search score with best param = 1.0

# %%
data = {'Technique' : ['Logistic Regression', "LR with only feedback columns ", 'Decision tree',
                       'Random forest', 'DT CV','RF CV','Tuned RS RF CV','Tuned GS RF CV'],
       'Score' : [logreg_score, logreg_feedback_score, DT_score, RF_score, CV_DT_score, CV_RF_score, RS_RF_score, GS_RF_score] }

result = pd.DataFrame(data)

# %%
result
# Out:
#                         Technique     Score
# 0             Logistic Regression  0.834008
# 1  LR with only feedback columns   0.804883
# 2                   Decision tree  0.925869
# 3                   Random forest  0.926441
# 4                           DT CV  0.926291
# 5                           RF CV  0.924326
# 6                  Tuned RS RF CV  0.952882
# 7                  Tuned GS RF CV  1.000000

# %% [markdown]
# # Dimensionality Reduction

# %% [markdown]
# ### 20. Perform the following tasks
#
# - Use PCA to reduce the number of dimensions such that the components capture 95% of the data
# - Train Logistic Regression, Decision Tree and Random Forest using the principle components
# - Calculate the accuracy scores for each of the models
# - Calculate the cross validation scores for each of the above models trained using principle components

# %% [markdown]
# #### We need to scale the data before using PCA which we have already done before

# %%
from sklearn.decomposition import PCA
#pca = PCA(10)# Initialize PCA object
pca = PCA(.95)
pca.fit(X_train)  # Fit the PCA object with the train data
# Out:
# PCA(n_components=0.95)

# %%
X_train_pca = pca.transform(X_train)  # PCs for the train data
X_test_pca = pca.transform(X_test)    # PCs for the test data

X_train_pca.shape, X_test_pca.shape
# Out:
# ((68187, 17), (22730, 17))

# %%
pca.explained_variance_
# Out:
# array([6.56249167, 4.67016428, 3.25158065, 1.84906655, 1.52855529,
#        1.34024597, 1.09697412, 1.01838954, 0.94021169, 0.88092802,
#        0.79598787, 0.73467932, 0.60038807, 0.58050698, 0.51886151,
#        0.48277017, 0.42963188])

# %%
lr = LogisticRegression()
lr.fit(X_train_pca, y_train)
logreg_score_pca = lr.score(X_test_pca, y_test)


dt = DecisionTreeClassifier()
dt.fit(X_train_pca, y_train)
DT_score_pca = dt.score(X_test_pca, y_test)

rf = RandomForestClassifier(max_depth = 20, max_features ='auto', min_samples_leaf = 5, n_estimators = 100)
rf.fit(X_train_pca, y_train)
RF_score_pca = rf.score(X_test_pca, y_test)

# %%
print("Log reg")
lr = LogisticRegression()
logreg_score_pca_cv = cross_val_score(lr,X_train_pca, y_train , cv = 5,n_jobs=-1).mean()
print("Decision Tree")
dt = DecisionTreeClassifier()
DT_score_pca_cv = cross_val_score(dt, X_train_pca, y_train, cv = 5,n_jobs=-1).mean()
print("RF")
rf = RandomForestClassifier(max_depth = 20, max_features ='sqrt', min_samples_leaf = 4, n_estimators = 100)
RF_score_pca_cv = cross_val_score(rf, X_train_pca, y_train, cv = 5,n_jobs=-1).mean()
# Out:
# Log reg
# Decision Tree
# RF

# %%
result = pd.DataFrame({'Algorithm' : ['Logistic Regression', 'Deision Tree', 'Random Forest'],
                      'Accuracy_score': [logreg_score_pca, DT_score_pca, RF_score_pca],
                      'Cross_val_score' : [logreg_score_pca_cv, DT_score_pca_cv, RF_score_pca_cv]})
result
# Out:
#              Algorithm  Accuracy_score  Cross_val_score
# 0  Logistic Regression        0.809327         0.810682
# 1         Deision Tree        0.854597         0.850250
# 2        Random Forest        0.906115         0.904161

# %% [markdown]
# # Pipeline - Automate and Simplyfy the process

# %%
#pip install --upgrade category_encoders

# %%
import pandas as pd
import numpy as np

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,LabelEncoder, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from category_encoders import OrdinalEncoder



numeric_features = ['Age', 'Flight_Distance', 'ArrivalDelayin_Mins']

feedback_features = ['Seat_comfort', 'Departure.Arrival.time_convenient', 'Food_drink',
       'Gate_location', 'Inflightwifi_service', 'Inflight_entertainment',
       'Online_support', 'Ease_of_Onlinebooking', 'Onboard_service',
       'Leg_room_service', 'Baggage_handling', 'Checkin_service',
       'Cleanliness', 'Online_boarding']

other_cat_cols =  ['Gender', 'CustomerType', 'TypeTravel', 'Class']


#TRANSFORMERS



numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())])


feedback_feature_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='not_captured')),
    ('label_encoder', OrdinalEncoder())
    #('scaler', StandardScaler())
])


other_cat_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='not_captured')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])


preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('feed_col', feedback_feature_transformer, feedback_features),
        ('other_cat_col', other_cat_transformer, other_cat_cols )
    ])

# %%
#Adding into Pipeline
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      #('PCA', PCA(n_components = 10)),
                      ('classifier', RandomForestClassifier(max_depth= 20,max_features= 'auto',min_samples_leaf= 4,n_estimators= 100))])

# %%
#Taking the raw data
data = df2.set_index("Id").join(df1.set_index("ID"))
data
# Out:
#                    Satisfaction    Seat_comfort  \
# Id
# 198671  neutral or dissatisfied            poor
# 193378                satisfied       excellent
# 174522                satisfied            good
# 191830                satisfied            good
# 221497                satisfied            good
# ...                         ...             ...
# 152951                satisfied  extremely poor
# 220134                satisfied            poor
# 174403                satisfied            good
# 224128                satisfied            good
# 186039  neutral or dissatisfied      acceptable
#
#        Departure.Arrival.time_convenient        Food_drink    Gate_location  \
# Id
# 198671                        acceptable        acceptable       manageable
# 193378                  need improvement         excellent       Convinient
# 174522                              good              good       manageable
# 191830                              good              good       manageable
# 221497                              good               NaN       Convinient
# ...                                  ...               ...              ...
# 152951                              good    extremely poor       Convinient
# 220134                              poor              poor     Inconvinient
# 174403                              good              good       manageable
# 224128                              poor         excellent  very convinient
# 186039                  need improvement  need improvement       manageable
#
#        Inflightwifi_service Inflight_entertainment Online_support  \
# Id
# 198671                 poor       need improvement           poor
# 193378           acceptable              excellent     acceptable
# 174522           acceptable              excellent      excellent
# 191830                 poor                   good           poor
# 221497                 good                   good           good
# ...                     ...                    ...            ...
# 152951     need improvement              excellent           good
# 220134                 good              excellent      excellent
# 174403                 good                   good      excellent
# 224128                 good                   good           good
# 186039                 good             acceptable           good
#
#        Ease_of_Onlinebooking   Onboard_service  ...       Cleanliness  \
# Id                                              ...
# 198671                  poor        acceptable  ...  need improvement
# 193378            acceptable              good  ...         excellent
# 174522      need improvement  need improvement  ...  need improvement
# 191830                  poor              poor  ...        acceptable
# 221497                  good              good  ...              good
# ...                      ...               ...  ...               ...
# 152951                  good              good  ...              good
# 220134                  good              good  ...              good
# 174403                  poor              poor  ...              poor
# 224128                  good              good  ...        acceptable
# 186039                  good              poor  ...              good
#
#        Online_boarding  Gender       CustomerType Age       TypeTravel  \
# Id
# 198671            poor    Male     Loyal Customer  30  Business travel
# 193378      acceptable  Female  disloyal Customer  20              NaN
# 174522       excellent  Female                NaN  55  Personal Travel
# 191830            poor    Male  disloyal Customer  24  Business travel
# 221497            good    Male     Loyal Customer  32  Business travel
# ...                ...     ...                ...  ..              ...
# 152951      acceptable  Female                NaN  46  Personal Travel
# 220134            good  Female     Loyal Customer  45              NaN
# 174403       excellent  Female     Loyal Customer  67              NaN
# 224128            good  Female     Loyal Customer  37  Business travel
# 186039            good    Male  disloyal Customer  43  Business travel
#
#            Class  Flight_Distance DepartureDelayin_Mins ArrivalDelayin_Mins
# Id
# 198671  Business             1354                    11                 8.0
# 193378  Business             1439                     6                 0.0
# 174522  Eco Plus              976                     4                 0.0
# 191830       Eco             2291                     0                 0.0
# 221497  Business             3974                     0                 0.0
# ...          ...              ...                   ...                 ...
# 152951       Eco             1143                     0                 0.0
# 220134  Business             3585                     1                 0.0
# 174403       Eco             2563                     3                 2.0
# 224128       Eco             1027                     0                 0.0
# 186039  Business             1491                    53                53.0
#
# [90917 rows x 23 columns]

# %%
#Getting X and y
X1 = data.drop(['Satisfaction', 'DepartureDelayin_Mins'], axis = 1)
y1 = data['Satisfaction']

# %%
#Data SPlit
X_trains, X_tests, y_trains, y_tests = train_test_split(X1,y1, random_state = 1, stratify = y)

# %%
X_trains.shape,y_trains.shape
# Out:
# ((68187, 21), (68187,))

# %%
#Fitting Pipeline 
clf.fit(X_trains, y_trains)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Flight_Distance',
#                                                    'ArrivalDelayin_Mins']),
#                                                  ('feed_col',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='not_captured',
#                                                                                  strategy='constant')),
#                                                                   ('label_encoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['Seat_comfort',
#                                                    'D...
#                                                    'Checkin_service',
#                                                    'Cleanliness',
#                                                    'Online_boarding']),
#                                                  ('other_cat_col',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='not_captured',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Gender', 'CustomerType',
#                                                    'TypeTravel', 'Class'])])),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=20, max_features='auto',
#                                         min_samples_leaf=4))])

# %%
#Getting score 
clf.score(X_tests, y_tests)
# Out:
# 0.9476462824461065

# %%
clf.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocessor',
#    ColumnTransformer(transformers=[('num',
#                                     Pipeline(steps=[('imputer', SimpleImputer()),
#                                                     ('scaler', StandardScaler())]),
#                                     ['Age', 'Flight_Distance',
#                                      'ArrivalDelayin_Mins']),
#                                    ('feed_col',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(fill_value='not_captured',
#                                                                    strategy='constant')),
#                                                     ('label_encoder',
#                                                      OrdinalEncoder())]),
#                                     ['Seat_comfort',
#                                      'Departure.Arrival.time_convenient...
#                                      'Inflight_entertainment', 'Online_support',
#                                      'Ease_of_Onlinebooking', 'Onboard_service',
#                                      'Leg_room_service', 'Baggage_handling',
#                                      'Checkin_service', 'Cleanliness',
#                                      'Online_boarding']),
#                                    ('other_cat_col',
#                                     Pipeline(steps=[('imputer',
#                                                      SimpleImputer(fill_value='not_captured',
#                                                                    strategy='constant')),
#                                                     ('onehot',
#                                                      OneHotEncoder(handle_unknown='ignore'))]),
#                                     ['Gender', 'CustomerType', 'TypeTravel',
#                                      'Class'])])),
#   ('classifier',
#    RandomForestClassifier(max_depth=20, max_features='auto', min_samples_leaf=4))],
#  'verbose': False,
#  'preprocessor': ColumnTransformer(transformers=[('num',
#                                   Pipeline(steps=[('imputer', SimpleImputer()),
#                                                   ('scaler', StandardScaler())]),
#                                   ['Age', 'Flight_Distance',
#                                    'ArrivalDelayin_Mins']),
#                                  ('feed_col',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(fill_value='not_captured',
#                                                                  strategy='constant')),
#                                                   ('label_encoder',
#                                                    OrdinalEncoder())]),
#                                   ['Seat_comfort',
#                                    'Departure.Arrival.time_convenient...
#                                    'Inflight_entertainment', 'Online_support',
#                                    'Ease_of_Onlinebooking', 'Onboard_service',
#                                    'Leg_room_service', 'Baggage_handling',
#                                    'Checkin_service', 'Cleanliness',
#                                    'Online_boarding']),
#                                  ('other_cat_col',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(fill_value='not_captured',
#                                                                  strategy='constant')),
#                                                   ('onehot',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   ['Gender', 'CustomerType', 'TypeTravel',
#                                    'Class'])]),
#  'classifier': RandomForestClassifier(max_depth=20, max_features='auto', min_samples_leaf=4),
#  'preprocessor__n_jobs': None,
#  'preprocessor__remainder': 'drop',
#  'preprocessor__sparse_threshold': 0.3,
#  'preprocessor__transformer_weights': None,
#  'preprocessor__transformers': [('num',
#    Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())]),
#    ['Age', 'Flight_Distance', 'ArrivalDelayin_Mins']),
#   ('feed_col',
#    Pipeline(steps=[('imputer',
#                     SimpleImputer(fill_value='not_captured', strategy='constant')),
#                    ('label_encoder', OrdinalEncoder())]),
#    ['Seat_comfort',
#     'Departure.Arrival.time_convenient',
#     'Food_drink',
#     'Gate_location',
#     'Inflightwifi_service',
#     'Inflight_entertainment',
#     'Online_support',
#     'Ease_of_Onlinebooking',
#     'Onboard_service',
#     'Leg_room_service',
#     'Baggage_handling',
#     'Checkin_service',
#     'Cleanliness',
#     'Online_boarding']),
#   ('other_cat_col',
#    Pipeline(steps=[('imputer',
#                     SimpleImputer(fill_value='not_captured', strategy='constant')),
#                    ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#    ['Gender', 'CustomerType', 'TypeTravel', 'Class'])],
#  'preprocessor__verbose': False,
#  'preprocessor__verbose_feature_names_out': True,
#  'preprocessor__num': Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler())]),
#  'preprocessor__feed_col': Pipeline(steps=[('imputer',
#                   SimpleImputer(fill_value='not_captured', strategy='constant')),
#                  ('label_encoder', OrdinalEncoder())]),
#  'preprocessor__other_cat_col': Pipeline(steps=[('imputer',
#                   SimpleImputer(fill_value='not_captured', strategy='constant')),
#                  ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#  'preprocessor__num__memory': None,
#  'preprocessor__num__steps': [('imputer', SimpleImputer()),
#   ('scaler', StandardScaler())],
#  'preprocessor__num__verbose': False,
#  'preprocessor__num__imputer': SimpleImputer(),
#  'preprocessor__num__scaler': StandardScaler(),
#  'preprocessor__num__imputer__add_indicator': False,
#  'preprocessor__num__imputer__copy': True,
#  'preprocessor__num__imputer__fill_value': None,
#  'preprocessor__num__imputer__keep_empty_features': False,
#  'preprocessor__num__imputer__missing_values': nan,
#  'preprocessor__num__imputer__strategy': 'mean',
#  'preprocessor__num__imputer__verbose': 'deprecated',
#  'preprocessor__num__scaler__copy': True,
#  'preprocessor__num__scaler__with_mean': True,
#  'preprocessor__num__scaler__with_std': True,
#  'preprocessor__feed_col__memory': None,
#  'preprocessor__feed_col__steps': [('imputer',
#    SimpleImputer(fill_value='not_captured', strategy='constant')),
#   ('label_encoder', OrdinalEncoder())],
#  'preprocessor__feed_col__verbose': False,
#  'preprocessor__feed_col__imputer': SimpleImputer(fill_value='not_captured', strategy='constant'),
#  'preprocessor__feed_col__label_encoder': OrdinalEncoder(),
#  'preprocessor__feed_col__imputer__add_indicator': False,
#  'preprocessor__feed_col__imputer__copy': True,
#  'preprocessor__feed_col__imputer__fill_value': 'not_captured',
#  'preprocessor__feed_col__imputer__keep_empty_features': False,
#  'preprocessor__feed_col__imputer__missing_values': nan,
#  'preprocessor__feed_col__imputer__strategy': 'constant',
#  'preprocessor__feed_col__imputer__verbose': 'deprecated',
#  'preprocessor__feed_col__label_encoder__cols': None,
#  'preprocessor__feed_col__label_encoder__drop_invariant': False,
#  'preprocessor__feed_col__label_encoder__handle_missing': 'value',
#  'preprocessor__feed_col__label_encoder__handle_unknown': 'value',
#  'preprocessor__feed_col__label_encoder__mapping': None,
#  'preprocessor__feed_col__label_encoder__return_df': True,
#  'preprocessor__feed_col__label_encoder__verbose': 0,
#  'preprocessor__other_cat_col__memory': None,
#  'preprocessor__other_cat_col__steps': [('imputer',
#    SimpleImputer(fill_value='not_captured', strategy='constant')),
#   ('onehot', OneHotEncoder(handle_unknown='ignore'))],
#  'preprocessor__other_cat_col__verbose': False,
#  'preprocessor__other_cat_col__imputer': SimpleImputer(fill_value='not_captured', strategy='constant'),
#  'preprocessor__other_cat_col__onehot': OneHotEncoder(handle_unknown='ignore'),
#  'preprocessor__other_cat_col__imputer__add_indicator': False,
#  'preprocessor__other_cat_col__imputer__copy': True,
#  'preprocessor__other_cat_col__imputer__fill_value': 'not_captured',
#  'preprocessor__other_cat_col__imputer__keep_empty_features': False,
#  'preprocessor__other_cat_col__imputer__missing_values': nan,
#  'preprocessor__other_cat_col__imputer__strategy': 'constant',
#  'preprocessor__other_cat_col__imputer__verbose': 'deprecated',
#  'preprocessor__other_cat_col__onehot__categories': 'auto',
#  'preprocessor__other_cat_col__onehot__drop': None,
#  'preprocessor__other_cat_col__onehot__dtype': numpy.float64,
#  'preprocessor__other_cat_col__onehot__handle_unknown': 'ignore',
#  'preprocessor__other_cat_col__onehot__max_categories': None,
#  'preprocessor__other_cat_col__onehot__min_frequency': None,
#  'preprocessor__other_cat_col__onehot__sparse': 'deprecated',
#  'preprocessor__other_cat_col__onehot__sparse_output': True,
#  'classifier__bootstrap': True,
#  'classifier__ccp_alpha': 0.0,
#  'classifier__class_weight': None,
#  'classifier__criterion': 'gini',
#  'classifier__max_depth': 20,
#  'classifier__max_features': 'auto',
#  'classifier__max_leaf_nodes': None,
#  'classifier__max_samples': None,
#  'classifier__min_impurity_decrease': 0.0,
#  'classifier__min_samples_leaf': 4,
#  'classifier__min_samples_split': 2,
#  'classifier__min_weight_fraction_leaf': 0.0,
#  'classifier__n_estimators': 100,
#  'classifier__n_jobs': None,
#  'classifier__oob_score': False,
#  'classifier__random_state': None,
#  'classifier__verbose': 0,
#  'classifier__warm_start': False}

# %%
#Adding into Pipeline
clf_1 = Pipeline(steps=[('preprocessor', preprocessor),
                      ('PCA', PCA(n_components = 10)),
                      ('classifier', RandomForestClassifier(max_depth= 20,max_features= 'auto',min_samples_leaf= 4,n_estimators= 100))])

# %%
#Getting score 
#Fitting Pipeline 
clf_1.fit(X_trains, y_trains)
clf_1.score(X_tests, y_tests)
# Out:
# 0.8904971403431589

# %% [markdown]
# #### Lets do grid search with pipelines

# %%
clf_tuned = Pipeline(steps=[('preprocessor', preprocessor),
                      # ('PCA', PCA(n_components = 10)),
                      ('classifier', RandomForestClassifier(max_depth= 20,max_features= 'auto',min_samples_leaf= 4,n_estimators= 100))])

# %%
import time
start = time.time()

# parameters = {'max_depth': [30, 40, 70],
#  'max_features': ['log2', 'sqrt'],
#  'min_samples_leaf': [1, 2, 4, 8],
#  'n_estimators': [100]}

parameters = [
    {
        'preprocessor__num__imputer__strategy': (['mean','median']),
        'classifier__max_depth': (30, 40),
        'classifier__max_features': (['log2','sqrt'])
    }
]


grid_search = GridSearchCV(clf_tuned, parameters,n_jobs=-1,cv = 5, verbose = 2,)
grid_search.fit(X_trains, y_trains)

end = time.time()
print((end-start)/60," minutes")
#Getting score 
grid_search.score(X_tests, y_tests)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# 1.3485207319259644  minutes
# 0.9491860976682798

# %%
grid_search.best_params_
# Out:
# {'classifier__max_depth': 40,
#  'classifier__max_features': 'sqrt',
#  'preprocessor__num__imputer__strategy': 'median'}

# %%
start = time.time()
parameters = [
    {
        'preprocessor__num__imputer__strategy': (['mean','median']),
        'classifier__max_depth': (30, 40,50,60,80,100),
        'classifier__max_features': (['log2','sqrt'])
    }
]
Random_search = RandomizedSearchCV(clf_tuned, parameters,n_jobs=-1,cv = 5, verbose = 3,n_iter=1)
Random_search.fit(X_trains, y_trains)

end = time.time()
print((end-start)/60," minutes")
#Getting score 
Random_search.score(X_tests, y_tests)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0.33193029165267945  minutes
# 0.9449626044874615

# %%
# Best parameters
grid_search.best_params_

# %% [markdown]
# # Conclusion:
#
# - Given some data, we have seen how to perform EDA for that dataset
# - The data that we had was not entirely continuous or categorical. Hence we improvised the analysis to draw insights
# - We used the same old bar-charts but the way we interpreted is unique to this problem
# - Beyond EDA, we have seen how to preprocess data and train Supervised Models with it
# - We finally put all the steps in one place and built a pipeline using the Sklearn's Pipeline function
#
# # Explore:
#
# - You can cluster different segments of customer to get more insights about their behaviours.
# - Create new features and select the best features to improve your model further.
#
# and more ----
